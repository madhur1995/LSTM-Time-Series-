# %%
# !pip install tensorflow

import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# '2.6.0'

# %%
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\lenovo\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas-datareader) (1.2.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas-datareader) (2.25.1)
# Requirement already satisfied: lxml in c:\users\lenovo\anaconda3\lib\site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)

# %%
import pandas_datareader as pdr

# %%
#key = "********************"

# key = "copy and paste here your api key authentication"

# %%
dataset = pdr.get_data_tiingo('AAPL', api_key = key)

# %%
dataset.tail()
# Out:
#                                    close      high     low     open  \
# symbol date
# AAPL   2021-11-30 00:00:00+00:00  165.30  165.5200  159.92  159.985
#        2021-12-01 00:00:00+00:00  164.77  170.3000  164.53  167.480
#        2021-12-02 00:00:00+00:00  163.76  164.2000  157.80  158.735
#        2021-12-03 00:00:00+00:00  161.84  164.9600  159.72  164.020
#        2021-12-06 00:00:00+00:00  165.32  167.8799  164.28  164.290
#
#                                      volume  adjClose   adjHigh  adjLow  \
# symbol date
# AAPL   2021-11-30 00:00:00+00:00  174048056    165.30  165.5200  159.92
#        2021-12-01 00:00:00+00:00  152423003    164.77  170.3000  164.53
#        2021-12-02 00:00:00+00:00  136739174    163.76  164.2000  157.80
#        2021-12-03 00:00:00+00:00  118023116    161.84  164.9600  159.72
#        2021-12-06 00:00:00+00:00  107496982    165.32  167.8799  164.28
#
#                                   adjOpen  adjVolume  divCash  splitFactor
# symbol date
# AAPL   2021-11-30 00:00:00+00:00  159.985  174048056      0.0          1.0
#        2021-12-01 00:00:00+00:00  167.480  152423003      0.0          1.0
#        2021-12-02 00:00:00+00:00  158.735  136739174      0.0          1.0
#        2021-12-03 00:00:00+00:00  164.020  118023116      0.0          1.0
#        2021-12-06 00:00:00+00:00  164.290  107496982      0.0          1.0

# %%
dataset.to_csv('Aapledataset.csv')

# %%
import pandas as pd
df = pd.read_csv('Aapledataset.csv')

# %%
df.head()
# Out:
#   symbol                       date   close    high     low    open    volume  \
# 0   AAPL  2016-12-08 00:00:00+00:00  112.12  112.43  110.60  110.86  27068316
# 1   AAPL  2016-12-09 00:00:00+00:00  113.95  114.70  112.31  112.31  34402627
# 2   AAPL  2016-12-12 00:00:00+00:00  113.30  115.00  112.49  113.29  26374377
# 3   AAPL  2016-12-13 00:00:00+00:00  115.19  115.92  113.75  113.84  43733811
# 4   AAPL  2016-12-14 00:00:00+00:00  115.19  116.20  114.98  115.04  34031834
#
#     adjClose    adjHigh     adjLow    adjOpen  adjVolume  divCash  splitFactor
# 0  26.380961  26.453902  26.023317  26.084493  108273264      0.0          1.0
# 1  26.811546  26.988015  26.425667  26.425667  137610508      0.0          1.0
# 2  26.658606  27.058603  26.468019  26.656253  105497508      0.0          1.0
# 3  27.103308  27.275071  26.764487  26.785664  174935244      0.0          1.0
# 4  27.103308  27.340953  27.053897  27.068014  136127336      0.0          1.0

# %%
df.tail()
# Out:
#      symbol                       date   close      high     low     open  \
# 1252   AAPL  2021-11-30 00:00:00+00:00  165.30  165.5200  159.92  159.985
# 1253   AAPL  2021-12-01 00:00:00+00:00  164.77  170.3000  164.53  167.480
# 1254   AAPL  2021-12-02 00:00:00+00:00  163.76  164.2000  157.80  158.735
# 1255   AAPL  2021-12-03 00:00:00+00:00  161.84  164.9600  159.72  164.020
# 1256   AAPL  2021-12-06 00:00:00+00:00  165.32  167.8799  164.28  164.290
#
#          volume  adjClose   adjHigh  adjLow  adjOpen  adjVolume  divCash  \
# 1252  174048056    165.30  165.5200  159.92  159.985  174048056      0.0
# 1253  152423003    164.77  170.3000  164.53  167.480  152423003      0.0
# 1254  136739174    163.76  164.2000  157.80  158.735  136739174      0.0
# 1255  118023116    161.84  164.9600  159.72  164.020  118023116      0.0
# 1256  107496982    165.32  167.8799  164.28  164.290  107496982      0.0
#
#       splitFactor
# 1252          1.0
# 1253          1.0
# 1254          1.0
# 1255          1.0
# 1256          1.0

# %%
df1 = df.reset_index()['close']

# %%
df1
# Out:
# 0       112.12
# 1       113.95
# 2       113.30
# 3       115.19
# 4       115.19
#          ...
# 1252    165.30
# 1253    164.77
# 1254    163.76
# 1255    161.84
# 1256    165.32
# Name: close, Length: 1257, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
# LSTM method to predict Time Series Forecasting for AAPL complany share value

# %%
dataset1 = pdr.get_data_tiingo('GOOG', api_key = key)

# %%
dataset1.tail()
# Out:
#                                     close       high      low      open  \
# symbol date
# GOOG   2021-11-30 00:00:00+00:00  2849.04  2932.5700  2841.32  2909.005
#        2021-12-01 00:00:00+00:00  2832.36  2929.9825  2830.00  2884.250
#        2021-12-02 00:00:00+00:00  2875.53  2893.5000  2819.64  2836.480
#        2021-12-03 00:00:00+00:00  2850.41  2904.2599  2823.00  2889.910
#        2021-12-06 00:00:00+00:00  2875.93  2887.0300  2812.94  2871.480
#
#                                    volume  adjClose    adjHigh   adjLow  \
# symbol date
# GOOG   2021-11-30 00:00:00+00:00  2079526   2849.04  2932.5700  2841.32
#        2021-12-01 00:00:00+00:00  1427289   2832.36  2929.9825  2830.00
#        2021-12-02 00:00:00+00:00  1062535   2875.53  2893.5000  2819.64
#        2021-12-03 00:00:00+00:00  1334374   2850.41  2904.2599  2823.00
#        2021-12-06 00:00:00+00:00  1109885   2875.93  2887.0300  2812.94
#
#                                    adjOpen  adjVolume  divCash  splitFactor
# symbol date
# GOOG   2021-11-30 00:00:00+00:00  2909.005    2079526      0.0          1.0
#        2021-12-01 00:00:00+00:00  2884.250    1427289      0.0          1.0
#        2021-12-02 00:00:00+00:00  2836.480    1062535      0.0          1.0
#        2021-12-03 00:00:00+00:00  2889.910    1334374      0.0          1.0
#        2021-12-06 00:00:00+00:00  2871.480    1109885      0.0          1.0

# %%
dataset2 = dataset1.reset_index()['close']

# %%
plt.plot(dataset2)
